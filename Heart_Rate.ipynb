# %%
with open("20190130_103416_hr.txt", 'r') as f:
    Time = f.read().split()[0::2]   
print(Time)
with open("20190130_103416_hr.txt", 'r') as f:
    Heart_rate = f.read().split()[1::2]
print( Heart_rate )
import matplotlib.pyplot as plt
plt.plot(Time, Heart_rate )
plt.rcParams["figure.figsize"] = 20,8
# Out:
# ['1548824657.426', '1548824658.399', '1548824659.447', '1548824660.437', '1548824661.438', '1548824662.436', '1548824663.453', '1548824664.431', '1548824665.441', '1548824666.460', '1548824667.451', '1548824668.929', '1548824669.438', '1548824670.436', '1548824671.432', '1548824672.419', '1548824673.384', '1548824674.874', '1548824676.918', '1548824676.919', '1548824677.877', '1548824678.892', '1548824679.876', '1548824680.888', '1548824681.900', '1548824682.882', '1548824683.897', '1548824684.882', '1548824685.899', '1548824686.885', '1548824687.884', '1548824688.854', '1548824689.867', '1548824690.895', '1548824691.852', '1548824692.829', '1548824693.883', '1548824694.867', '1548824695.875', '1548824696.837', '1548824697.846', '1548824698.814', '1548824699.832', '1548824700.849', '1548824701.847', '1548824702.857', '1548824703.832', '1548824704.819', '1548824705.843', '1548824706.793', '1548824707.832', '1548824708.832', '1548824709.798', '1548824710.835', '1548824711.847', '154882
# ...
